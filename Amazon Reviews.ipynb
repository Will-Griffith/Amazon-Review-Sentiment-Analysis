# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# Link to data file(5 core digital music review): http://jmcauley.ucsd.edu/data/amazon/

# %%
df = pd.read_json('Digital_Music_5.json', lines=True)

# %%
df.head()
# Out:
#          asin helpful  overall  \
# 0  5555991584  [3, 3]        5
# 1  5555991584  [0, 0]        5
# 2  5555991584  [2, 2]        5
# 3  5555991584  [1, 1]        5
# 4  5555991584  [1, 1]        4
#
#                                           reviewText   reviewTime  \
# 0  It's hard to believe "Memory of Trees" came ou...  09 12, 2006
# 1  A clasically-styled and introverted album, Mem...   06 3, 2001
# 2  I never thought Enya would reach the sublime h...  07 14, 2003
# 3  This is the third review of an irish album I w...   05 3, 2000
# 4  Enya, despite being a successful recording art...  01 17, 2008
#
#        reviewerID          reviewerName                       summary  \
# 0  A3EBHHCZO6V2A4  Amaranth "music fan"       Enya's last great album
# 1   AZPWAXJG9OJXV             bethtexas      Enya at her most elegant
# 2  A38IRL0X2T4DPF           bob turnley               The best so far
# 3  A22IK3I6U76GX0                 Calle  Ireland produces good music.
# 4  A1AISPOIIHTHXX           Cloud "..."        4.5; music to dream to
#
#    unixReviewTime
# 0      1158019200
# 1       991526400
# 2      1058140800
# 3       957312000
# 4      1200528000

# %%
df.shape
# Out:
# (64706, 9)

# %% [markdown]
# Our goal is to predict if a review was positive or negative based on it's review text, to practice sentiment anlysis. We will drop all but two columns.

# %%
#Converting review score from range of 1-5 to binary positive or negative
#if the review is greater than 3 we will label it as positive otherwise negative
df['is_positive'] = np.where(df['overall'] > 3, 1, 0)

#Drop all columns except is_positive and text
df = df.drop(df.loc[:,~df.columns.isin(['is_positive', 'reviewText'])], axis=1)

# %%
df.is_positive.value_counts()
# Out:
# 1    52116
# 0    12590
# Name: is_positive, dtype: int64

# %% [markdown]
# Class balance is a little skewed we will have to take this into account.
#
# According to Wang and Greiner(2005) Support vector machines with a bag of words approach will give us the best results for sentiment classification. We will use Sci kit learns Count Vectorizer method to create our bag of words on train and use those words to predict on test.
#
# Source:https://pdfs.semanticscholar.org/aa3d/afab5bd4112b3f55929582bfec48139ff4c3.pdf

# %%
#Set X and Y
X = df.reviewText
y = df.is_positive

#Split data with stratisfy to ensure class balance stays the same on train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.20)

# %%
from sklearn.feature_extraction.text import CountVectorizer
#Using built in stop words list, and setting the minimum document frequency to 2.
vec = CountVectorizer(stop_words='english', min_df=2)
vec.fit(X_train)
X_train = vec.transform(X_train)
X_test = vec.transform(X_test)
#Print our features "Bag of Words"
print('\nnumber of features: ', len(vec.get_feature_names()),'\n')
print(vec.get_feature_names())
# Out:
# number of features:  49502
#
# ['00', '000', '000th', '000x', '001', '007', '00am', '00s', '01', '02', '03', '0304', '0310', '04', '047', '05', '06', '07', '08', '09', '095', '0f', '0r', '10', '100', '1000', '10000', '10000000', '1000000000000000000000000000000000000', '1000s', '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '100a', '100mph', '100my', '100not', '100recommended', '100s', '100th', '100x', '101', '1010', '1011', '1012', '1013', '1014', '1015', '1016', '1017', '1018', '1019', '101st', '102', '1020', '1021', '1022', '103', '10304', '104', '105', '106', '107', '108', '109', '10a', '10aerials', '10after', '10album', '10all', '10also', '10and', '10another', '10aqueous', '10are', '10as', '10atwa', '10back', '10beats', '10best', '10black', '10blood', '10bonus', '10bounce', '10bring', '10bump', '10cc', '10chop', '10circles', '10closing', '10cold', '10coming', '10concept', '10cruel', '10deer', '10disc', '10don', '10echo', '10favorite', '10flow', '10forest', '10from', '10genre', '10get', '10good', '10gotta', '10great', '10guess', '10guest', '10have', '10he', '10heat', '10high', '10home', '10hotel', '10how', '10i', '10if', '10in', '10ish', '10it', '10its', '10jet', '10just', '10keep', '10key', '10life', '10like', '10liquid', '10little', '10love', '10lyrics', '10many', '10michael', '10min', '10money', '10music', '10my', '10needles', '10nelly', '10no', '10northern', '10not', '10nothing', '10now', '10offensiveness', '10oh', '10one', '10only', '10originality', '10overall', '10p', '10patiently', '10picture', '10playa', '10playboy', '10pm', '10poor', '10pretty', '10production', '10raspberry', '10replay', '10s', '10say', '10she', '10shimmy', '10sky', '10so', '10stand', '10take', '10th', '10the', '10theme', '10there', '10this', '10those', '10till', '10top', '10total', '10toxicity', '10two', '10voice', '10wake', '10warning', '10we', '10what', '10when', '10wish', '10x', '10years', '10you', '10yrs', '11', '110', '111', '1112', '112', '113', '114', '115', '1150', '118', '119', '11am', '11th', '12', '120', '1200', '120my', '122', '123', '1234', '124', '125', '127', '128', '128th', '12play', '12s', '12th', '12x', '13', '130', '131', '132', '133', '134', '135mm', '136', '137', '138', '13th', '14', '140', '1400', '142', '143', '1472', '14th', '15', '150', '1500', '151', '154', '156', '157', '15th', '16', '160', '1600', '168', '169', '16th', '17', '170', '174', '175', '177', '17th', '18', '180', '1800', '180g', '180gram', '1810', '182', '185', '187', '1879', '187um', '18th', '19', '1900', '1900s', '1901', '1903', '1911', '1914', '1915', '1920', '1920s', '1921', '1925', '1926', '1927', '1928', '1929', '1930', '1930s', '1931', '1933', '1934', '1936', '1937', '1938', '1939', '1940', '1940s', '1941', '1942', '1943', '1945', '1947', '1948', '1949', '1950', '1950s', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1960s', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1969s', '1970', '1970s', '1971', '1971disc', '1972', '1973', '1974', '1975', '1975got', '1976', '1977', '1978', '1978s', '1979', '1979s', '198', '1980', '1980s', '1981', '1982', '1982s', '1983', '1984', '1985', '1986', '1987', '1987s', '1988', '1989', '199', '1990', '1990s', '1991', '1992', '1993', '1993s', '1994', '1995', '1995s', '1996', '1996s', '1997', '1998', '1999', '1999hotel', '19th', '1cd', '1da', '1luv', '1rip', '1s', '1sing', '1st', '1the', '1they', '1when', '20', '200', '2000', '2000s', '2001', '2002', '2002a', '2003', '2004', '2005', '2005s', '2006', '2007', '2008', '2008s', '2009', '2009s', '201', '2010', '2010s', '2011', '2011i', '2011s', '2012', '2013', '2013will', '2014', '2016', '2017', '2018', '2019', '2020', '2024', '203', '2040', '206', '20s', '20th', '20x', '20years', '21', '210', '211', '2112', '212', '213', '213check', '214', '215', '219', '21rst', '21st', '22', '220', '222', '225', '229', '22nd', '23', '230', '231', '234', '23rd', '24', '242', '24k', '24s', '24th', '25', '250', '2525', '255', '25th', '26', ' ...

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

clf = LinearSVC(class_weight='balanced',C=.1)
clf.fit(X_train, y_train)

print('train',cross_val_score(clf, X_train, y_train, cv=5))
# Out:
# train [ 0.83745412  0.82856867  0.83278594  0.83413833  0.83549073]

# %%
print('test',cross_val_score(clf, X_test, y_test, cv=5))
# Out:
# test [ 0.82425647  0.82193897  0.83314021  0.82225657  0.81600309]

# %%
from sklearn.metrics import confusion_matrix, classification_report

train_pred = clf.predict(X_train)
test_pred = clf.predict(X_test)

print('train confusion matrix and report:')
print(confusion_matrix(y_train, train_pred))
print(classification_report(y_train, train_pred))

print('test confusion matrix and report:')
print(confusion_matrix(y_test, test_pred))
print(classification_report(y_test, test_pred))
# Out:
# train confusion matrix and report:
# [[ 9876   196]
#  [ 1562 40130]]
#              precision    recall  f1-score   support
#
#           0       0.86      0.98      0.92     10072
#           1       1.00      0.96      0.98     41692
#
# avg / total       0.97      0.97      0.97     51764
#
# test confusion matrix and report:
# [[1687  831]
#  [1283 9141]]
#              precision    recall  f1-score   support
#
#           0       0.57      0.67      0.61      2518
#           1       0.92      0.88      0.90     10424
#
# avg / total       0.85      0.84      0.84     12942

# %% [markdown]
# Very overfit on train. we can see we get very high accuracy when we don't cross validate.
